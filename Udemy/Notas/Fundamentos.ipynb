# %% [markdown]
# # Primeiros passos

# %%
print('Primeiro programa')
1+2

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
print(35 +5 /2)
print(59/ 5)
# Out:
# 37.5
# 11.8

# %% [markdown]
# # Tipos basicos

# %%
print(True)
print(False)
print(1.2 +1)
print('Aqui eu falooooo')
print('Você é' + 3 * 'muitoosss')
#print(" " + 3 + "a")
print([1, 2, 2])
print({'nome':'pedro', 'idade': '25'})
# Out:
# True
# False
# 2.2
# Aqui eu falooooo
# Você émuitoosssmuitoosssmuitoosss
# [1, 2, 2]
# {'nome': 'pedro', 'idade': '25'}

# %% [markdown]
# # Variaveis

# %%
a = 10
b = 5
print(a+b)
a = "Sou top"
print(a+b)
#eu posso mudar o tipo de uma variavel,mas ele ainda sebe o que estou trabalhando
# Out:
# 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37568\2755722347.py in <module>
#       3 print(a+b)
#       4 a = "Sou top"
# ----> 5 print(a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# String

# %%
frase = 'Python é uma linguagem excelente'
'Py' not in frase
'ing' in frase
len(frase)
frase.upper()
frase.lower()
frase
frase = frase.upper()
frase.split()
frase.split('A')
# dir(str)
# help(str.center)
# Out:
# Help on method_descriptor:
#
# center(self, width, fillchar=' ', /) unbound builtins.str method
#     Return a centered string of length width.
#
#     Padding is done using the specified fill character (default is a space).

# %% [markdown]
# Para depois: Metodos magicos

# %%
a = '123'
b = ' de Oliveira 4'
a + b
a.__add__(b)
str.__add__(a, b)
dir(str)
len(a)
a.__len__()
'1' in a
# dir(str)
# Out:
# True

# %% [markdown]
# Listas

# %%
lista = []
type(lista)
# dir(lista)
# help(list)
len(lista)
lista.append(1)
lista.append(2)
lista
len(lista)

nova_lista = [1, 5, 'Aninha', 3, 14]
nova_lista
nova_lista.remove(5)
nova_lista
nova_lista.reverse()
nova_lista
# Out:
# [14, 3, 'Aninha', 1]

# %%
lista = [1, 5, 'Rebeca', 'Ana', 'João', 3.1415]
lista
lista.index('João')
# lista.index(42)

lista[3] = 'Layanny'
lista
1 in lista
'Rebeca' in lista
'Pedro' in lista
lista[0]
lista[4]
# lista[6]

lista[-1]
lista[-6]
# Out:
# 1

# %%
lista = ['Ana','Lia','Rui','Pedro']
lista[1:3]
lista[1:-1]
lista[1:]
lista[:-1]
lista[:]
lista[::2]
lista[::-1]
lista.sort()
lista
del lista[2]
lista
# Out:
# ['Ana', 'Lia', 'Rui']

# %% [markdown]
# Tupla

# %%
tupla = tuple()
tupla = ()
dir(tupla)
# help(tuple)
type(tupla)
tupla = ('um')
type(tupla)
tupla = ('um',)
type(tupla)
tupla[0]
# tupla[0] = 'Novo'
cores = ('verde', 'amarelo','azul', 'azul', 'branco')
cores[0]
cores[-1]
cores[1:]
cores.index('amarelo')
cores.count('azul')
len(cores)
# Out:
# 5

# %% [markdown]
# Dicionário

# %%
pessoa = {'nome': 'Prof. Ana', 'idade': 38, 'cursos': ['inglês', 'português']}
type(pessoa)
dir(dict)
len(pessoa)

pessoa
pessoa['nome']
pessoa['idade']
pessoa['cursos']
pessoa['cursos'][1]
pessoa['cursos'].append('espanhol')
pessoa.keys()
pessoa.values()
pessoa.items()
pessoa.get('idade')
pessoa.get('tags')
pessoa.get('tags', [])
# Out:
# []

# %%
pessoa = {'nome': 'prof. ALberto', 'idade': 43, 'cursos':['Python', 'Java']}
pessoa['idade'] = 44
pessoa['cursos'].append('Angular')
pessoa
pessoa.pop('idade')

pessoa
pessoa.update({'idade': 40, 'sexo': 'M'})
pessoa
del pessoa['cursos']
pessoa
pessoa.clear()
pessoa
# Out:
# {}

# %% [markdown]
# Conjuntos

# %%
a = {1, 2, 3}
type(a)
# a[0]
a = set('cod3r')
print(a)
print(3 in a, 4 not in a)
{1, 2, 3} == {3, 2, 1, 3}

# Operações
c1 = {1, 2}
c2 = {2, 3}
c1.union(c2)
c1.intersection(c2)
# Out:
# {'d', 'o', 'r', '3', 'c'}
# False True
# {2}

# %% [markdown]
# Interpolação

# %%
from string import Template
nome, idade = 'Ana', 30
print('Nome: %s Idade: %d'%(nome, idade) )
print("Nome: {0} Idade: {1}".format(nome,idade))
print(f"Nome: {nome} Idade: {idade}") # py >= 3.6
s = Template('Nome: $n Idade: $i')
print(s.substitute(n=nome, i=idade))
# Out:
# Nome: Ana Idade: 30
# Nome: Ana Idade: 30
# Nome: Ana Idade: 30
# Nome: Ana Idade: 30

# %%
valor = 'b'

# %%
not valor.isnumeric()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 not valor.isnumeric()
#
# AttributeError: 'float' object has no attribute 'isnumeric'

# %%
if  valor is None:
    print("Valor vazio")
elif not valor.isnumeric():
    print("Insira um valor númerico")
# Out:
# Insira um valor númerico
